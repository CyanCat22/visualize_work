# %%
import numpy as np
import matplotlib.pyplot as plt
import csv
import sys
import pandas as pd

# %%
path = r"D:\work\zufe\Visualize\python_xs2018.xlsx"
df = pd.read_excel(path)
print(df)

# %%
fig = plt.figure() 
ax = fig.add_subplot(1, 1, 1)
ax.boxplot(df['Sale'])
plt.show()

# %%
import seaborn as sns # 小提琴图
sns.violinplot(x=df['Age'], y = df['Sex'])
sns.despine() # 去除上侧和右侧轴线
plt.show()

# %%
# 散点图
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
x = df['ID']
y = df['Income']
z = df['Sale']
ax.scatter(x, y, c='r', marker='s', s=60, label = 'Income') # marker散点形状
ax.scatter(x, z, c='g', s=60, label = 'Sale')
plt.legend() # 加图例
plt.show()

# %%
var = df.groupby(['Sex']).sum().stack()
# 对同样性别的数据值进行求和
t = var.unstack() # 将var中的列变成行
x = t['Sale']
label1 = t.index
plt.axis('equal') #使x轴和y轴长度相等
plt.pie(x, labels=label1, autopct="%1.lf%%")  # 用format格式化输入百分比
plt.show()

# %%
fig = plt.figure()

canva = fig.add_subplot(1,1, 1)
canva.scatter(df['Age'], df['Sale'], s=df['Income']*10)
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import csv
import sys
import pandas as pd
path = r"D:\work\zufe\Visualize\第一次作业\unemployment-rate-1948-2010.csv"
file = pd.read_csv(path)
print(file)
id = file['id']
period = file['Period']
years = file['Year'] 
# print(years)
plt.figure()

# plt.scatter(x=years, )

# %%
# 导入所需库
import matplotlib.pyplot as plt
import numpy as np

# 准备数据
x = np.array([1, 2, 3, 4])
y = np.array([2, 4, 6, 8])
sizes = np.array([50, 100, 150, 200])
colors = ['r', 'g', 'b', 'y']
labels = ['A', 'B', 'C', 'D']

# 创建散点气泡图
plt.scatter(x, y, s=sizes, c=colors, alpha=0.5)

# 添加标签
for i, label in enumerate(labels):
    plt.annotate(label, (x[i], y[i]))

# 显示图形
plt.show()

# %%
from pyecharts.charts import Bar
import pandas as pd
# from pyecharts import options as opts
import csv
data = []
path = r"D:\work\zufe\Visualize\hot-dog-places.csv"
file = pd.read_csv(path)
print(file)

# with open(path) as f:
#     reader = csv.reader(f)
#     for datarow in reader:
#         data.append(datarow)
# print(data)
# datax = data[0]
# datay_A = data[1]
# datay_B = data[2]
# datay_C = data[3]
# (
#     Bar()
#     .add_xaxis(datax)
#     .add_yaxis("热狗大比赛", datay_A)
#     .add_yaxis('',datay_B)
#     .render_notebook()
# )

# %%
import pandas as pd
from pyecharts.charts import Bar
from pyecharts import options as opts
data = pd.DataFrame({
    "区域": ["A区", "B区", "C区"],
    "总销量": [23, 32, 14],
    "上衣销量": [3, 5, 10],
    "裤子销量": [15, 5, 1],
    "鞋袜销量": [5, 22, 3]
})
bar = (
    Bar(init_opts=opts.InitOpts(width="900px", height="500px"))
    .add_xaxis(data["区域"].tolist())
    .add_yaxis("总销量", data["总销量"].tolist())
)
bar.render_notebook()

# %%
# from pyecharts import Line
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

path = r"D:\work\zufe\Visualize\第一次作业\used_cars.csv"
text = pd.read_csv(path)
# print(text)
years = text['year']
prices = text['price']
miles = text['miles']
horsepower = text['horsepower']
# 选取的列为year, price,miles, door
# print(years)
# print(prices)
# print(miles)
# print(horsepower)
plt.figure()
# 拟合曲线
plt.scatter(x=prices, y=years, s = miles * 0.005, c='green', alpha=0.3)
plt.xlabel('price')
plt.ylabel('year')
# poly = np.polyfit(prices, years, deg=2)
# plt.plot(np.polyval(poly, years),years,  c='r')
plt.show()

# %%
from pyecharts.globals import ThemeType
# CurrentConfig.NOTEBOOK_TYPE = NotebookType.JUPYTER_NOTEBOOK

# from pyecharts.globals import CurrentConfig, NotebookType,ThemeType
# CurrentConfig.NOTEBOOK_TYPE = NotebookType.JUPYTER_NOTEBOOK

from pyecharts.charts import Bar

bar = Bar()
bar.add_xaxis(["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"])
bar.add_yaxis("商家A", [5, 20, 36, 10, 75, 90])
# render 会生成本地 HTML 文件，默认会在当前目录生成 render.html 文件
# 也可以传入路径参数，如 bar.render("mycharts.html")
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="531c4a7f5399413d818065407a4749bd" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_531c4a7f5399413d818065407a4749bd = echarts.init(
#                     document.getElementById('531c4a7f5399413d818065407a4749bd'), 'white', {renderer: 'canvas'});
#                 var option_531c4a7f5399413d818065407a4749bd = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "legendHoverLink": true,
#             "data": [
#                 5,
#                 20,
#                 36,
#                 10,
#                 75,
#                 90
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {}
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#                 chart_531c4a7f5399413d818065407a4749bd.setOption(option_531c4a7f5399413d818065407a4749bd);
#         });
#     </script>
